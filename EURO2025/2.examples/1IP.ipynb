# %% [markdown]
# # The 1-LP model

# %% [markdown]
# $$
# \begin{array}{crrcrrrl}
# \max z & = & x_1 & + & 3x_2  \\
# s.t. & \\
#     &&  x_1 & + &  x_2 & \le & 14 \\
#     &&  -2x_1 & + &  3x_2 & \le & 12 \\
#     &&   2x_1 & - &   x_2 & \le & 12 \\
#     &&   x_1 & , &   x_2 & \ge & 0
# \end{array}
# $$

# %% [markdown]
# ------

# %% [markdown]
# # The JuMP model

# %%
using JuMP, Gurobi

# %%
modLP = Model( )

@variable(modLP, x1 ≥ 0)
@variable(modLP, x2 ≥ 0)
@objective(modLP, Max, x1 + 3x2)
@constraint(modLP, cst1, x1 + x2 ≤ 14)
@constraint(modLP, cst2, -2x1 + 3x2 ≤ 12)
@constraint(modLP, cst3, 2x1 - x2 ≤ 12)

print(modLP)
# Out:
# $$ \begin{aligned}
# \max\quad & x1 + 3 x2\\
# \text{Subject to} \quad & x1 + x2 \leq 14\\
#  & -2 x1 + 3 x2 \leq 12\\
#  & 2 x1 - x2 \leq 12\\
#  & x1 \geq 0\\
#  & x2 \geq 0\\
# \end{aligned} $$

# %%
set_optimizer(modLP, Gurobi.Optimizer)
set_silent(modLP)
optimize!(modLP)
# Out:
# Set parameter Username
# Set parameter LicenseID to value 2585370
# Academic license - for non-commercial use only - expires 2025-11-15

# %%
@show is_solved_and_feasible(modLP)
@show objective_value(modLP)
@show value(x1), value(x2)
# Out:
# is_solved_and_feasible(modLP) = true
# objective_value(modLP) = 30.0
# (value(x1), value(x2)) = (6.0, 8.0)
# (6.0, 8.0)
